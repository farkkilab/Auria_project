# %% [markdown]
# # Load package

# %%
import scanpy as sc

import pandas as pd

# %% [markdown]
# # Load data

# %%
test = sc.read('/Users/wenqchen/Desktop/Projects/Auria/Data/scRNA/scRNA_all.h5ad')

# %%
test.obs['subtype'].unique()
# Out:
# ['HER2+', 'TNBC', 'ER+']
# Categories (3, object): ['ER+', 'HER2+', 'TNBC']

# %%
test_sub = test[test.obs['subtype'] == 'TNBC']
test_sub.obs

# %%
test.obs
# Out:
#                          donor_id  percent_mito  nCount_RNA  nFeature_RNA  \
# index
# CID3586_AAGACCTCAGCATGAG  CID3586      1.506221        4581          1689
# CID3586_AAGGTTCGTAGTACCT  CID3586      5.793743        1726           779
# CID3586_ACCAGTAGTTGTGGCC  CID3586      1.383238        1229           514
# CID3586_ACCCACTAGATGTCGG  CID3586      1.923077        1352           609
# CID3586_ACTGATGGTCAACTGT  CID3586     13.325541        1711           807
# ...                           ...           ...         ...           ...
# CID4398_TCAGGTAGTACTCAAC  CID4398      2.698336        6189          1251
# CID4398_TCTATTGTCGCCATAA  CID4398      3.057905        4611           719
# CID4398_TCTTTCCCAGTAAGCG  CID4398      3.682625        2987           887
# CID4398_TGCCCATGTTACGGAG  CID4398      2.208325        5117           870
# CID4398_TTGAACGTCCTATTCA  CID4398      2.126067        6679          1231
#
#                          celltype_major     celltype_minor  \
# index
# ...

# %%
adata = sc.read('/Users/wenqchen/Desktop/Projects/Auria/Data/scRNA/TNBC_adata.h5ad')

# %%
adata.obs
# Out:
#                          orig.ident  nCount_RNA  nFeature_RNA  \
# CID4465_AAACGGGTCATCGATG    CID4465        1277           799
# CID4465_AAACGGGTCGGAAACG    CID4465         478           339
# CID4465_AAAGATGAGGTGTGGT    CID4465        1495           878
# CID4465_AAAGCAATCCTTTACA    CID4465         723           457
# CID4465_AACCATGGTACGCTGC    CID4465        1977          1074
# ...                             ...         ...           ...
# CID3963_GAACCTACACAGATTC    CID3963        1316           566
# CID3963_GCATGCGGTTCGAATC    CID3963        1372           575
# CID3963_GTACGTAGTGAGGGAG    CID3963        3247          1167
# CID3963_TATTACCTCTTACCTA    CID3963        6043          1712
# CID3963_TTCTCCTTCCACGACG    CID3963        2814          1029
#
#                                               NAME  Patient  Percent_mito  \
# CID4465_AAACGGGTCATCGATG  CID4465_AAACGGGTCATCGATG  CID4465      2.662490
# ...

# %%
adata.obs['subtype'].unique()
# Out:
# ['TNBC']
# Categories (1, object): ['TNBC']

# %%
adata.uns.spatial

# %%
adata.obs
# Out:
#                                    array_row  array_col  tumour_cells  \
# AAACAACGAATAGTTC-1_1160920F-7-7            0         16           1.0
# AAACAAGTATCTCCCA-1_1142243F-10-10         50        102           NaN
# AAACAAGTATCTCCCA-1_1160920F-7-7           50        102           1.0
# AAACAAGTATCTCCCA-1_CID4465-6-6            50        102           NaN
# AAACAATCTACTAGCA-1_1160920F-7-7            3         43           1.0
# ...                                      ...        ...           ...
# TTGTTTGTATTACACG-1_1160920F-7-7           73         41           1.0
# TTGTTTGTGTAAATTC-1_1142243F-10-10          7         51           1.0
# TTGTTTGTGTAAATTC-1_1160920F-7-7            7         51           1.0
# TTGTTTGTGTAAATTC-1_CID4465-6-6             7         51           1.0
# TTGTTTGTGTAAATTC-1_CID44971-9-9            7         51           NaN
#
#                                         EMT       EPI batch  B_cells_Memory  \
# ...

# %%
test
# Out:
# AnnData object with n_obs × n_vars = 11971 × 14664
# ...

# %%
test.var
# Out:
#              mt  n_cells_by_counts-0  mean_counts-0  log1p_mean_counts-0  \
# SAMD11    False                   94       0.043292             0.042381
# NOC2L     False                  789       0.530647             0.425691
# KLHL17    False                  235       0.117017             0.110661
# PLEKHN1   False                   23       0.009859             0.009810
# PERM1     False                   11       0.004715             0.004704
# ...         ...                  ...            ...                  ...
# C21orf58  False                   68       0.030433             0.029979
# PCNT      False                  240       0.119589             0.112961
# DIP2A     False                  411       0.213030             0.193122
# S100B     False                  258       0.156022             0.144985
# PRMT2     False                  809       0.566224             0.448667
#
#           pct_dropout_by_counts-0  total_counts-0  log1p_total_counts-0  \
# ...

# %%
test.obs
# Out:
#                                    array_row  array_col  tumour_cells  \
# AAACAACGAATAGTTC-1_1160920F-7-7            0         16           1.0
# AAACAAGTATCTCCCA-1_1142243F-10-10         50        102           NaN
# AAACAAGTATCTCCCA-1_1160920F-7-7           50        102           1.0
# AAACAAGTATCTCCCA-1_CID4465-6-6            50        102           NaN
# AAACAATCTACTAGCA-1_1160920F-7-7            3         43           1.0
# ...                                      ...        ...           ...
# TTGTTTGTATTACACG-1_1160920F-7-7           73         41           1.0
# TTGTTTGTGTAAATTC-1_1142243F-10-10          7         51           1.0
# TTGTTTGTGTAAATTC-1_1160920F-7-7            7         51           1.0
# TTGTTTGTGTAAATTC-1_CID4465-6-6             7         51           1.0
# TTGTTTGTGTAAATTC-1_CID44971-9-9            7         51           NaN
#
#                                         EMT       EPI batch  B_cells_Memory  \
# ...
